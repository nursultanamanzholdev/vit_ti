# %%
#!pip install tensorflow_addons

# %%
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow import keras
import scipy

from tensorflow.keras import optimizers

from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import Input, Flatten, BatchNormalization, Dense
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import numpy as np
import matplotlib.pyplot as plt
import gc
# Out:
# C:\Users\fano\anaconda3\envs\rs\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpu,True)

# %%
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
(train_data, train_label), (test_data, test_label) = cifar10.load_data()
train_label = to_categorical(train_label)
test_label = to_categorical(test_label)
train_data = (train_data/255.).astype("float32")
test_data = (test_data/255.).astype("float32")

# %%
X_train, X_valid, y_train, y_valid = train_test_split(train_data,train_label,random_state=seed,shuffle=True,train_size=0.9)

# %%
batch_size = 32
datagen = ImageDataGenerator(rotation_range=15,
                             width_shift_range=0.2,
                             zoom_range=0.2,
                             horizontal_flip=True,
                             height_shift_range=0.2,
                             shear_range=0.2
                            )

train_generator = datagen.flow(X_train, y_train, batch_size=batch_size)

# %%
checkpoint_vit = ModelCheckpoint(r'C:\Users\fano\Desktop\weights\vit4_6.h5',
    verbose=1,
    monitor='val_loss',
    save_best_only=True,
    mode='auto'
)

# %%
class PatchEmbedding(tf.keras.layers.Layer):
  def __init__(self , size , num_of_patches , projection_dim):
    super().__init__()

    self.size=size
    self.num_of_patches= num_of_patches + 1
    self.projection_dim=projection_dim

    self.projection=tf.keras.layers.Dense(projection_dim)

    self.clsToken= tf.Variable(tf.keras.initializers.GlorotNormal()(shape=(1 , 1 , projection_dim)) , trainable=True)
    self.positionalEmbedding = tf.keras.layers.Embedding(self.num_of_patches , projection_dim)


  def call(self, inputs):
    patches = tf.image.extract_patches(inputs ,
                                       sizes=[1 , self.size , self.size , 1],
                                       strides=[1 , self.size , self.size , 1],
                                       rates=[1 ,1 ,1 ,1],
                                       padding="VALID",)
    patches=tf.reshape(patches, (tf.shape(inputs)[0], -1, self.size * self.size *3))
    patches= self.projection(patches)

    # repeat cls token length of batch size
    clsToken = tf.repeat(self.clsToken , tf.shape(inputs)[0] , 0)
    patches = tf.concat((clsToken, patches) , axis=1)
    # create position number for each patch
    positions = tf.range(0 , self.num_of_patches , 1)[tf.newaxis , ...]
    positionalEmbedding = self.positionalEmbedding(positions)

    #print(positionalEmbedding)
    patches= patches + positionalEmbedding
    return patches

# %%
class TransformerLayer(tf.keras.layers.Layer):
  def __init__(self , d_model , heads , mlp_rate , dropout_rate=0.1):
    super().__init__()

    self.layernorm_1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.mha= tf.keras.layers.MultiHeadAttention(heads, d_model//heads , dropout=dropout_rate)

    self.layernorm_2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.mlp = tf.keras.Sequential([
                                    tf.keras.layers.Dense(d_model * mlp_rate , activation="gelu"),
                                    tf.keras.layers.Dropout(dropout_rate),
                                    tf.keras.layers.Dense(d_model , activation="gelu"),
                                    tf.keras.layers.Dropout(dropout_rate)
    ])
  def call(self , inputs , training=True):
    out_1 = self.layernorm_1(inputs)
    out_1 = self.mha(out_1 , out_1 ,training=training)
    out_1 = inputs + out_1

    out_2= self.layernorm_2(out_1)
    out_2=self.mlp(out_2 , training=training)
    out_2 = out_1 + out_2

    return out_2

# %%
class TransformerEncoder(tf.keras.layers.Layer):
  def __init__(self , d_model , heads , mlp_rate , num_layers=1 , dropout_rate=0.1):
    super().__init__()

    self.encoders = [TransformerLayer(d_model , heads , mlp_rate , dropout_rate) for _ in range(num_layers)]

  def call(self , inputs , training=True):
    x =inputs

    for layer in self.encoders:
      x = layer(x , training=training)

    return x

# %%
class ViT(tf.keras.Model):
  def __init__(self , num_classes , patch_size , num_of_patches , d_model , heads , num_layers , mlp_rate , dropout_rate=0.1):
    super().__init__()

    self.patchEmbedding = PatchEmbedding(patch_size , num_of_patches , d_model)
    self.encoder = TransformerEncoder(d_model , heads , mlp_rate  ,num_layers , dropout_rate)

    self.prediction = tf.keras.Sequential([
                                           tf.keras.layers.Dropout(0.3),
                                           tf.keras.layers.Dense(mlp_rate * d_model , activation="gelu"),
                                           tf.keras.layers.Dropout(0.2),
                                           tf.keras.layers.Dense(num_classes, activation="softmax")


  ])
  def call(self , inputs ,  training=True):
    patches = self.patchEmbedding(inputs)
    encoderResult = self.encoder(patches, training=training)

    clsResult = encoderResult[: , 0 , :]

    prediction = self.prediction(clsResult,
                                 training=training)
    return prediction

# %%
# def scheduler(epoch, lr):
#     if epoch < 10:
#         return lr
#     else:
#         if epoch % 2:
#             return lr * tf.math.exp(-0.1)
#         else:
#             return lr

# callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

# %%
def lr_warmup_cosine_decay(global_step,
                           warmup_steps,
                           hold = 0,
                           total_steps=0,
                           start_lr=0.0001,
                           target_lr=1e-3):
    # Cosine decay
    learning_rate = 0.5 * target_lr * (1 + np.cos(np.pi * (global_step - warmup_steps - hold) / float(total_steps - warmup_steps - hold)))

    # Target LR * progress of warmup (=1 at the final warmup step)
    warmup_lr = target_lr * (global_step / warmup_steps)

    # Choose between `warmup_lr`, `target_lr` and `learning_rate` based on whether `global_step < warmup_steps` and we're still holding.
    # i.e. warm up if we're still warming up and use cosine decayed lr otherwise
    if hold > 0:
        learning_rate = np.where(global_step > warmup_steps + hold,
                                 learning_rate, target_lr)

    learning_rate = np.where(global_step < warmup_steps, warmup_lr, learning_rate)
    return learning_rate

# %%
from tensorflow.keras import backend as K

class WarmupCosineDecay(tf.keras.callbacks.Callback):
    def __init__(self, total_steps=0, warmup_steps=0, start_lr=0.0001, target_lr=1e-3, hold=0):

        super(WarmupCosineDecay, self).__init__()
        self.start_lr = start_lr
        self.hold = hold
        self.total_steps = total_steps
        self.global_step = 1
        self.target_lr = target_lr
        self.warmup_steps = warmup_steps
        self.lrs = []

    def on_epoch_end(self, epoch, logs=None):
        self.global_step = self.global_step + 1
        lr = self.model.optimizer.lr.numpy()
        self.lrs.append(lr)

    def on_epoch_begin(self, epoch, logs=None):
        lr = lr_warmup_cosine_decay(global_step=self.global_step,
                                    total_steps=self.total_steps,
                                    warmup_steps=self.warmup_steps,
                                    start_lr=self.start_lr,
                                    target_lr=self.target_lr,
                                    hold=self.hold)
        print(f"Learining rate is {lr}")
        K.set_value(self.model.optimizer.lr, lr)

# %%
# If already batched
total_steps = 100
# If not batched
#total_steps = len(train_set)/config['BATCH_SIZE']*config['EPOCHS']
# 5% of the steps
warmup_steps = 10

callback = WarmupCosineDecay(total_steps=total_steps,
                             warmup_steps=warmup_steps,
                             hold=int(warmup_steps/2),
                             start_lr=0.0001,
                             target_lr=0.001)

# %%
vitClassifier = ViT(num_classes=10, patch_size=16, num_of_patches=196,
                d_model=192, heads=3, num_layers=10,
                mlp_rate=4,dropout_rate=0.1)

# %%
next(iter(train_generator))[0].shape
# Out:
# (32, 32, 32, 3)

# %%
def build_model():
    inputs = Input(shape=(32,32,3))
    x = tf.keras.layers.Lambda(lambda image: tf.image.resize(image,(224,224)))(inputs)
    y = vitClassifier(x)

    return Model(inputs=inputs,outputs=y)

# %%
vit = build_model()

# %%
vit.summary()
vit.compile(
    optimizer=tf.keras.optimizers.Adam(lr=0.001),
    #optimizer = tf.keras.optimizers.SGD(lr=0.01,momentum=0.9),
    loss=tf.keras.losses.CategoricalCrossentropy(),
  metrics=[
      tf.keras.metrics.CategoricalAccuracy(name="accuracy")
  ],
)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  lambda (Lambda)             (None, 224, 224, 3)       0
#
#  vi_t (ViT)                  (None, 10)                4790218
#
# =================================================================
# Total params: 4,790,218
# Trainable params: 4,790,218
# Non-trainable params: 0
# _________________________________________________________________
# C:\Users\fano\anaconda3\envs\rs\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
history = vit.fit(train_generator,
                    epochs=100,
                    validation_data=(X_valid, y_valid),
                    callbacks=[callback]
                   )
#print("\nTest Accuracy: ", accuracy_score(np.argmax(test_label, axis=1), np.argmax(model.predict(test_data), axis=1)))
# Out:
# Learining rate is 0.0001
# Epoch 1/100
# 1407/1407 [==============================] - 226s 154ms/step - loss: 1.9802 - accuracy: 0.2635 - val_loss: 1.7057 - val_accuracy: 0.3672
# Learining rate is 0.0002
# Epoch 2/100
# 1407/1407 [==============================] - 216s 154ms/step - loss: 1.7395 - accuracy: 0.3562 - val_loss: 1.5563 - val_accuracy: 0.4280
# Learining rate is 0.0003
# Epoch 3/100
# 1407/1407 [==============================] - 216s 154ms/step - loss: 1.6174 - accuracy: 0.4080 - val_loss: 1.5012 - val_accuracy: 0.4544
# Learining rate is 0.0004
# Epoch 4/100
# 1407/1407 [==============================] - 219s 156ms/step - loss: 1.5445 - accuracy: 0.4389 - val_loss: 1.3922 - val_accuracy: 0.5028
# Learining rate is 0.0005
# Epoch 5/100
# 1407/1407 [==============================] - 220s 156ms/step - loss: 1.5006 - accuracy: 0.4564 - val_loss: 1.4126 - val_accuracy: 0.4906
# Learining rate is 0.0006
# Epoch 6/100
# 1407/1407 [==============================] - 219s 156ms/step - loss: 1.4707 - accuracy: 0.4691 - val_loss: 1.3938 - val_accuracy: 0.4684
# Learining rate is 0.0007
# Epoch 7/100
# 1407/1407 [==============================] - 219s 156ms/step - loss: 1.4509 - accuracy: 0.4798 - val_loss: 1.3544 - val_accuracy: 0.5094
# Learining rate is 0.0008
# Epoch 8/100
# 1407/1407 [==============================] - 219s 156ms/step - loss: 1.4323 - accuracy: 0.4860 - val_loss: 1.3322 - val_accuracy: 0.5118
# Learining rate is 0.0009000000000000001
# Epoch 9/100
# 1407/1407 [==============================] - 221s 157ms/step - loss: 1.4237 - accuracy: 0.4892 - val_loss: 1.2200 - val_accuracy: 0.5558
# Learining rate is 0.001
# Epoch 10/100
# 1407/1407 [==============================] - 220s 156ms/step - loss: 1.4028 - accuracy: 0.5001 - val_loss: 1.1690 - val_accuracy: 0.5744
# Learining rate is 0.001
# Epoch 11/100
# 1407/1407 [==============================] - 220s 156ms/step - loss: 1.3537 - accuracy: 0.5198 - val_loss: 1.2899 - val_accuracy: 0.5340
# Learining rate is 0.001
# Epoch 12/100
# 1407/1407 [==============================] - 220s 157ms/step - loss: 1.3323 - accuracy: 0.5272 - val_loss: 1.1297 - val_accuracy: 0.5962
# Learining rate is 0.001
# Epoch 13/100
# 1407/1407 [==============================] - 223s 159ms/step - loss: 1.3004 - accuracy: 0.5399 - val_loss: 1.1845 - val_accuracy: 0.5816
# Learining rate is 0.001
# Epoch 14/100
# 1407/1407 [==============================] - 221s 157ms/step - loss: 1.2577 - accuracy: 0.5552 - val_loss: 1.1479 - val_accuracy: 0.5874
# Learining rate is 0.001
# Epoch 15/100
# 1407/1407 [==============================] - 223s 159ms/step - loss: 1.2489 - accuracy: 0.5636 - val_loss: 1.0905 - val_accuracy: 0.6104
# Learining rate is 0.0009996585300715115
# Epoch 16/100
# 1407/1407 [==============================] - 223s 158ms/step - loss: 1.2146 - accuracy: 0.5721 - val_loss: 1.0506 - val_accuracy: 0.6234
# Learining rate is 0.0009986345866928941
# Epoch 17/100
# 1407/1407 [==============================] - 223s 158ms/step - loss: 1.1877 - accuracy: 0.5864 - val_loss: 1.0688 - val_accuracy: 0.6286
# Learining rate is 0.0009969295684476367
# Epoch 18/100
# 1407/1407 [==============================] - 221s 157ms/step - loss: 1.1607 - accuracy: 0.5943 - val_loss: 1.0342 - val_accuracy: 0.6396
# Learining rate is 0.000994545804185573
# Epoch 19/100
# 1407/1407 [==============================] - 220s 156ms/step - loss: 1.1416 - accuracy: 0.6003 - val_loss: 1.0386 - val_accuracy: 0.6366
# Learining rate is 0.000991486549841951
# Epoch 20/100
# 1407/1407 [==============================] - 220s 157ms/step - loss: 1.1251 - accuracy: 0.6086 - val_loss: 1.0234 - val_accuracy: 0.6408
# Learining rate is 0.0009877559839902184
# Epoch 21/100
# 1407/1407 [==============================] - 220s 156ms/step - loss: 1.1011 - accuracy: 0.6168 - val_loss: 1.0228 - val_accuracy: 0.6398
# Learining rate is 0.0009833592021345938
# Epoch 22/100
# 1407/1407 [==============================] - 220s 156ms/step - loss: 1.0916 - accuracy: 0.6214 - val_loss: 0.9735 - val_accuracy: 0.6692
# Learining rate is 0.0009783022097502204
# Epoch 23/100
# 1407/1407 [==============================] - 220s 156ms/step - loss: 1.0637 - accuracy: 0.6308 - val_loss: 0.9041 - val_accuracy: 0.6854
# Learining rate is 0.0009725919140804099
# Epoch 24/100
# 1407/1407 [==============================] - 219s 156ms/step - loss: 1.0490 - accuracy: 0.6398 - val_loss: 0.9421 - val_accuracy: 0.6614
# Learining rate is 0.0009662361147021779
# Epoch 25/100
# 1407/1407 [==============================] - 219s 156ms/step - loss: 1.0260 - accuracy: 0.6434 - val_loss: 0.9027 - val_accuracy: 0.6806
# Learining rate is 0.0009592434928729616
# Epoch 26/100
# 1407/1407 [==============================] - 220s 157ms/step - loss: 1.0110 - accuracy: 0.6521 - val_loss: 1.0098 - val_accuracy: 0.6530
# Learining rate is 0.0009516235996730644
# Epoch 27/100
# 1407/1407 [==============================] - 222s 158ms/step - loss: 0.9938 - accuracy: 0.6596 - val_loss: 0.9000 - val_accuracy: 0.6776
# Learining rate is 0.0009433868429600309
# Epoch 28/100
# 1407/1407 [==============================] - 221s 157ms/step - loss: 0.9742 - accuracy: 0.6650 - val_loss: 0.8765 - val_accuracy: 0.7028
# Learining rate is 0.0009345444731527642
# Epoch 29/100
# 1407/1407 [==============================] - 221s 157ms/step - loss: 0.9884 - accuracy: 0.6593 - val_loss: 0.9436 - val_accuracy: 0.6844
# Learining rate is 0.0009251085678648072
# Epoch 30/100
# 1407/1407 [==============================] - 221s 157ms/step - loss: 0.9364 - accuracy: 0.6775 - val_loss: 0.9063 - val_accuracy: 0.6924
# Learining rate is 0.0009150920154077753
# Epoch 31/100
# 1407/1407 [==============================] - 219s 156ms/step - loss: 0.9279 - accuracy: 0.6820 - val_loss: 0.8656 - val_accuracy: 0.6986
# Learining rate is 0.0009045084971874737
# Epoch 32/100
# 1407/1407 [==============================] - 222s 158ms/step - loss: 0.9477 - accuracy: 0.6730 - val_loss: 0.8255 - val_accuracy: 0.7126
# Learining rate is 0.0008933724690167417
# Epoch 33/100
# 1407/1407 [==============================] - 222s 158ms/step - loss: 0.9013 - accuracy: 0.6914 - val_loss: 0.8639 - val_accuracy: 0.7102
# Learining rate is 0.0008816991413705516
# Epoch 34/100
# 1407/1407 [==============================] - 222s 158ms/step - loss: 0.8753 - accuracy: 0.7012 - val_loss: 0.8686 - val_accuracy: 0.7092
# Learining rate is 0.0008695044586103295
# Epoch 35/100
# 1407/1407 [==============================] - 222s 158ms/step - loss: 0.8646 - accuracy: 0.7018 - val_loss: 0.8034 - val_accuracy: 0.7224
# Learining rate is 0.0008568050772058762
# Epoch 36/100
# 1407/1407 [==============================] - 222s 158ms/step - loss: 0.8604 - accuracy: 0.7067 - val_loss: 0.9124 - val_accuracy: 0.6950
# Learining rate is 0.0008436183429846313
# Epoch 37/100
# 1407/1407 [==============================] - 221s 157ms/step - loss: 0.8346 - accuracy: 0.7148 - val_loss: 0.8282 - val_accuracy: 0.7206
# Learining rate is 0.0008299622674393614
# Epoch 38/100
# 1407/1407 [==============================] - 220s 156ms/step - loss: 0.8163 - accuracy: 0.7196 - val_loss: 0.7588 - val_accuracy: 0.7438
# Learining rate is 0.0008158555031266255
# Epoch 39/100
# 1407/1407 [==============================] - 220s 156ms/step - loss: 0.8020 - accuracy: 0.7273 - val_loss: 0.8098 - val_accuracy: 0.7296
# Learining rate is 0.0008013173181896282
# Epoch 40/100
# 1407/1407 [==============================] - 219s 156ms/step - loss: 0.7882 - accuracy: 0.7336 - val_loss: 0.7287 - val_accuracy: 0.7568
# Learining rate is 0.0007863675700402526
# Epoch 41/100
# 1407/1407 [==============================] - 219s 155ms/step - loss: 0.7692 - accuracy: 0.7381 - val_loss: 0.7494 - val_accuracy: 0.7522
# Learining rate is 0.0007710266782362247
# Epoch 42/100
# 1407/1407 [==============================] - 219s 155ms/step - loss: 0.7653 - accuracy: 0.7417 - val_loss: 0.7590 - val_accuracy: 0.7430
# Learining rate is 0.0007553155965904535
# Epoch 43/100
# 1407/1407 [==============================] - 218s 155ms/step - loss: 0.7380 - accuracy: 0.7493 - val_loss: 0.7949 - val_accuracy: 0.7360
# Learining rate is 0.0007392557845506433
# Epoch 44/100
# 1407/1407 [==============================] - 218s 155ms/step - loss: 0.7328 - accuracy: 0.7505 - val_loss: 0.8119 - val_accuracy: 0.7290
# Learining rate is 0.0007228691778882692
# Epoch 45/100
# 1407/1407 [==============================] - 219s 155ms/step - loss: 0.7194 - accuracy: 0.7567 - val_loss: 0.7708 - val_accuracy: 0.7436
# Learining rate is 0.0007061781587369518
# Epoch 46/100
# 1407/1407 [==============================] - 219s 156ms/step - loss: 0.7064 - accuracy: 0.7600 - val_loss: 0.7520 - val_accuracy: 0.7492
# Learining rate is 0.0006892055250211552
# Epoch 47/100
# 1407/1407 [==============================] - 304s 216ms/step - loss: 0.6817 - accuracy: 0.7694 - val_loss: 0.7758 - val_accuracy: 0.7454
# Learining rate is 0.0006719744593169641
# Epoch 48/100
# 1407/1407 [==============================] - 289s 205ms/step - loss: 0.6770 - accuracy: 0.7698 - val_loss: 0.7647 - val_accuracy: 0.7444
# Learining rate is 0.0006545084971874737
# Epoch 49/100
# 1407/1407 [==============================] - 218s 155ms/step - loss: 0.6579 - accuracy: 0.7769 - val_loss: 0.7678 - val_accuracy: 0.7552
# Learining rate is 0.0006368314950360416
# Epoch 50/100
# 1407/1407 [==============================] - 217s 154ms/step - loss: 0.6444 - accuracy: 0.7828 - val_loss: 0.7019 - val_accuracy: 0.7622
# Learining rate is 0.0006189675975213093
# Epoch 51/100
# 1407/1407 [==============================] - 219s 155ms/step - loss: 0.6206 - accuracy: 0.7905 - val_loss: 0.8191 - val_accuracy: 0.7486
# Learining rate is 0.0006009412045785051
# Epoch 52/100
# 1407/1407 [==============================] - 220s 156ms/step - loss: 0.6136 - accuracy: 0.7920 - val_loss: 0.7462 - val_accuracy: 0.7658
# Learining rate is 0.000582776938092065
# Epoch 53/100
# 1407/1407 [==============================] - 220s 157ms/step - loss: 0.6065 - accuracy: 0.7952 - val_loss: 0.6993 - val_accuracy: 0.7630
# Learining rate is 0.0005644996082651017
# Epoch 54/100
# 1407/1407 [==============================] - 222s 158ms/step - loss: 0.5849 - accuracy: 0.8004 - val_loss: 0.7108 - val_accuracy: 0.7732
# Learining rate is 0.000546134179731651
# Epoch 55/100
# 1407/1407 [==============================] - 221s 157ms/step - loss: 0.5719 - accuracy: 0.8060 - val_loss: 0.6910 - val_accuracy: 0.7780
# Learining rate is 0.000527705737457985
# Epoch 56/100
# 1407/1407 [==============================] - 221s 157ms/step - loss: 0.5617 - accuracy: 0.8096 - val_loss: 0.6818 - val_accuracy: 0.7706
# Learining rate is 0.000509239452479565
# Epoch 57/100
# 1407/1407 [==============================] - 220s 157ms/step - loss: 0.5502 - accuracy: 0.8131 - val_loss: 0.6873 - val_accuracy: 0.7770
# Learining rate is 0.0004907605475204352
# Epoch 58/100
# 1407/1407 [==============================] - 220s 156ms/step - loss: 0.5321 - accuracy: 0.8190 - val_loss: 0.7063 - val_accuracy: 0.7700
# Learining rate is 0.00047229426254201515
# Epoch 59/100
# 1407/1407 [==============================] - 220s 156ms/step - loss: 0.5142 - accuracy: 0.8248 - val_loss: 0.7669 - val_accuracy: 0.7668
# Learining rate is 0.00045386582026834903
# Epoch 60/100
# 1407/1407 [==============================] - 249s 177ms/step - loss: 0.5005 - accuracy: 0.8324 - val_loss: 0.6679 - val_accuracy: 0.7878
# Learining rate is 0.0004355003917348985
# Epoch 61/100
# 1407/1407 [==============================] - 314s 223ms/step - loss: 0.4924 - accuracy: 0.8315 - val_loss: 0.6865 - val_accuracy: 0.7830
# Learining rate is 0.000417223061907935
# Epoch 62/100
# 1407/1407 [==============================] - 228s 162ms/step - loss: 0.4770 - accuracy: 0.8386 - val_loss: 0.6692 - val_accuracy: 0.7908
# Learining rate is 0.0003990587954214949
# Epoch 63/100
# 1407/1407 [==============================] - 219s 155ms/step - loss: 0.4593 - accuracy: 0.8427 - val_loss: 0.6947 - val_accuracy: 0.7858
# Learining rate is 0.00038103240247869074
# Epoch 64/100
# 1407/1407 [==============================] - 218s 155ms/step - loss: 0.4484 - accuracy: 0.8479 - val_loss: 0.7048 - val_accuracy: 0.7828
# Learining rate is 0.0003631685049639586
# Epoch 65/100
# 1407/1407 [==============================] - 218s 155ms/step - loss: 0.4407 - accuracy: 0.8512 - val_loss: 0.6951 - val_accuracy: 0.7910
# Learining rate is 0.00034549150281252633
# Epoch 66/100
# 1407/1407 [==============================] - 219s 156ms/step - loss: 0.4188 - accuracy: 0.8572 - val_loss: 0.7358 - val_accuracy: 0.7910
# Learining rate is 0.0003280255406830359
# Epoch 67/100
# 1407/1407 [==============================] - 216s 153ms/step - loss: 0.4221 - accuracy: 0.8572 - val_loss: 0.7138 - val_accuracy: 0.7886
# Learining rate is 0.00031079447497884486
# Epoch 68/100
# 1407/1407 [==============================] - 216s 154ms/step - loss: 0.4035 - accuracy: 0.8635 - val_loss: 0.7429 - val_accuracy: 0.7900
# Learining rate is 0.00029382184126304836
# Epoch 69/100
# 1407/1407 [==============================] - 216s 154ms/step - loss: 0.3917 - accuracy: 0.8668 - val_loss: 0.7205 - val_accuracy: 0.7796
# Learining rate is 0.0002771308221117309
# Epoch 70/100
# 1407/1407 [==============================] - 216s 154ms/step - loss: 0.3828 - accuracy: 0.8700 - val_loss: 0.7433 - val_accuracy: 0.7866
# Learining rate is 0.0002607442154493568
# Epoch 71/100
# 1407/1407 [==============================] - 216s 154ms/step - loss: 0.3645 - accuracy: 0.8723 - val_loss: 0.7436 - val_accuracy: 0.7824
# Learining rate is 0.0002446844034095466
# Epoch 72/100
# 1407/1407 [==============================] - 216s 154ms/step - loss: 0.3621 - accuracy: 0.8769 - val_loss: 0.7462 - val_accuracy: 0.7926
# Learining rate is 0.00022897332176377528
# Epoch 73/100
# 1407/1407 [==============================] - 217s 154ms/step - loss: 0.3480 - accuracy: 0.8835 - val_loss: 0.7147 - val_accuracy: 0.7900
# Learining rate is 0.00021363242995974742
# Epoch 74/100
# 1407/1407 [==============================] - 217s 155ms/step - loss: 0.3375 - accuracy: 0.8844 - val_loss: 0.7824 - val_accuracy: 0.7854
# Learining rate is 0.00019868268181037185
# Epoch 75/100
# 1407/1407 [==============================] - 220s 156ms/step - loss: 0.3270 - accuracy: 0.8885 - val_loss: 0.7825 - val_accuracy: 0.7978
# Learining rate is 0.00018414449687337466
# Epoch 76/100
# 1407/1407 [==============================] - 217s 154ms/step - loss: 0.3200 - accuracy: 0.8914 - val_loss: 0.7627 - val_accuracy: 0.7916
# Learining rate is 0.0001700377325606388
# Epoch 77/100
# 1407/1407 [==============================] - 219s 155ms/step - loss: 0.3068 - accuracy: 0.8972 - val_loss: 0.7278 - val_accuracy: 0.7974
# Learining rate is 0.00015638165701536866
# Epoch 78/100
# 1407/1407 [==============================] - 217s 154ms/step - loss: 0.3014 - accuracy: 0.8987 - val_loss: 0.7915 - val_accuracy: 0.7904
# Learining rate is 0.00014319492279412388
# Epoch 79/100
# 1407/1407 [==============================] - 216s 154ms/step - loss: 0.2832 - accuracy: 0.9032 - val_loss: 0.7962 - val_accuracy: 0.7926
# Learining rate is 0.0001304955413896705
# Epoch 80/100
# 1407/1407 [==============================] - 217s 154ms/step - loss: 0.2816 - accuracy: 0.9050 - val_loss: 0.7558 - val_accuracy: 0.8026
# Learining rate is 0.00011830085862944851
# Epoch 81/100
# 1407/1407 [==============================] - 218s 155ms/step - loss: 0.2781 - accuracy: 0.9070 - val_loss: 0.7878 - val_accuracy: 0.8002
# Learining rate is 0.00010662753098325839
# Epoch 82/100
# 1407/1407 [==============================] - 219s 155ms/step - loss: 0.2640 - accuracy: 0.9103 - val_loss: 0.8340 - val_accuracy: 0.7956
# Learining rate is 9.549150281252633e-05
# Epoch 83/100
# 1407/1407 [==============================] - 219s 156ms/step - loss: 0.2646 - accuracy: 0.9105 - val_loss: 0.7868 - val_accuracy: 0.7970
# Learining rate is 8.490798459222476e-05
# Epoch 84/100
# 1407/1407 [==============================] - 219s 156ms/step - loss: 0.2554 - accuracy: 0.9142 - val_loss: 0.7916 - val_accuracy: 0.7960
# Learining rate is 7.489143213519301e-05
# Epoch 85/100
# 1407/1407 [==============================] - 219s 155ms/step - loss: 0.2498 - accuracy: 0.9145 - val_loss: 0.8060 - val_accuracy: 0.7974
# Learining rate is 6.545552684723583e-05
# Epoch 86/100
# 1407/1407 [==============================] - 217s 154ms/step - loss: 0.2436 - accuracy: 0.9189 - val_loss: 0.7967 - val_accuracy: 0.7994
# Learining rate is 5.6613157039969057e-05
# Epoch 87/100
# 1407/1407 [==============================] - 217s 154ms/step - loss: 0.2341 - accuracy: 0.9200 - val_loss: 0.8397 - val_accuracy: 0.7982
# Learining rate is 4.8376400326935575e-05
# Epoch 88/100
# 1407/1407 [==============================] - 217s 154ms/step - loss: 0.2298 - accuracy: 0.9219 - val_loss: 0.8023 - val_accuracy: 0.8018
# Learining rate is 4.075650712703849e-05
# Epoch 89/100
# 1407/1407 [==============================] - 216s 154ms/step - loss: 0.2325 - accuracy: 0.9224 - val_loss: 0.8317 - val_accuracy: 0.7988
# Learining rate is 3.376388529782209e-05
# Epoch 90/100
# 1407/1407 [==============================] - 235s 167ms/step - loss: 0.2266 - accuracy: 0.9239 - val_loss: 0.8282 - val_accuracy: 0.8004
# Learining rate is 2.7408085919590266e-05
# Epoch 91/100
# 1407/1407 [==============================] - 313s 223ms/step - loss: 0.2243 - accuracy: 0.9242 - val_loss: 0.8336 - val_accuracy: 0.7990
# Learining rate is 2.1697790249779635e-05
# Epoch 92/100
# 1407/1407 [==============================] - 311s 221ms/step - loss: 0.2195 - accuracy: 0.9245 - val_loss: 0.8350 - val_accuracy: 0.8002
# Learining rate is 1.6640797865406288e-05
# Epoch 93/100
# 1407/1407 [==============================] - 236s 168ms/step - loss: 0.2148 - accuracy: 0.9286 - val_loss: 0.8410 - val_accuracy: 0.7998
# Learining rate is 1.22440160097817e-05
# Epoch 94/100
# 1407/1407 [==============================] - 215s 153ms/step - loss: 0.2137 - accuracy: 0.9289 - val_loss: 0.8333 - val_accuracy: 0.8006
# Learining rate is 8.513450158049108e-06
# Epoch 95/100
# 1407/1407 [==============================] - 216s 153ms/step - loss: 0.2083 - accuracy: 0.9297 - val_loss: 0.8500 - val_accuracy: 0.7992
# Learining rate is 5.454195814427021e-06
# Epoch 96/100
# 1407/1407 [==============================] - 216s 154ms/step - loss: 0.2106 - accuracy: 0.9284 - val_loss: 0.8472 - val_accuracy: 0.7996
# Learining rate is 3.0704315523631954e-06
# Epoch 97/100
# 1407/1407 [==============================] - 216s 154ms/step - loss: 0.2137 - accuracy: 0.9271 - val_loss: 0.8491 - val_accuracy: 0.7996
# Learining rate is 1.3654133071059894e-06
# Epoch 98/100
# 1407/1407 [==============================] - 216s 154ms/step - loss: 0.2140 - accuracy: 0.9278 - val_loss: 0.8474 - val_accuracy: 0.8008
# Learining rate is 3.4146992848854695e-07
# Epoch 99/100
# 1407/1407 [==============================] - 216s 153ms/step - loss: 0.2070 - accuracy: 0.9299 - val_loss: 0.8482 - val_accuracy: 0.7998
# Learining rate is 0.0
# Epoch 100/100
# 1407/1407 [==============================] - 216s 154ms/step - loss: 0.2171 - accuracy: 0.9268 - val_loss: 0.8482 - val_accuracy: 0.7998

# %%
# save the model !!!

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
results = vit.evaluate(test_data,test_label, batch_size=32, verbose=1)
print("test loss, test acc:", results)
# Out:
# 313/313 [==============================] - 16s 51ms/step - loss: 0.8220 - accuracy: 0.7966
# test loss, test acc: [0.8220232129096985, 0.7965999841690063]
